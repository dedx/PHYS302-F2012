# %%
from scipy import *from scipy.integrate import odeintfrom pylab import *g=9.8 #gravitational constantR=5. #Radius of pipephi0=20.*pi/180. #20 degreesphi1=50.*pi/180. #50 degreesdef deriv(y,t):    return array([y[1],-(g/R)*sin(y[0])])time = linspace(0.0,20.0,1000)phiinit = [phi0,0.]phi = 180./pi*odeint(deriv,phiinit,time)approx = phi0*(180./pi)*cos(sqrt(g/R)*time)    figure()plot(time,phi[:,0],'b-',label='$Numerical$',linewidth=2.0)plot(time,approx,'r--',label='$Approximation$',linewidth=2.0)legend(loc=2)          #puts legend in upper left cornerxlabel('t')ylabel('$\phi$')title('Skateboard')grid(True)show()

# %% [markdown]
# Skateboard Equation is $\frac{d^2\phi}{dt^2} = -(g/R) \sin(\phi(t))$
